# %%
# %load_ext autoreload
# %autoreload all
# Out:
# Failed to read module file 'C:\Users\yy\AppData\Local\Programs\Python\Python311\Lib\functools.py' for module 'functools': UnicodeDecodeError
# Traceback (most recent call last):
#   File "c:\Users\yy\Desktop\codes_PhD\pipeline_HERO\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\yy\Desktop\codes_PhD\pipeline_HERO\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\yy\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1206, in _gcd_import
# ...

# %%
import sys
from pathlib import Path

# Add the parent directory to sys.path so we can import src
sys.path.insert(0, str(Path().resolve().parent)) 
# Importing necessary libraries and modules
import polars as pl 
from src.pipeline_hero.config import Config, Tokenizer_vocabs
import pipeline_hero.tokenizer as tokenizer

# %% [markdown]
# # mlm tokenizer

# %%
# load data concept
mlm_tokens_list = pl.read_parquet(Tokenizer_vocabs.data_vocab)["code"].unique().to_list()

#tokenizer_mlm = tokenizer.MedicalCodeTokenizer(vocab=mlm_tokens_list, special_tokens=Tokenizer_vocabs.sppecial_tokens_mlm)
tokenizer_mlm = tokenizer.CodeWiseTokenizer(path_tokenizer = Tokenizer_vocabs.tokenizer_mlm_path)

tokenizer_mlm.save_tokenizer(Tokenizer_vocabs.tokenizer_mlm_path)
